# %%
import zipfile
import os

# Here we have specified the path to the .zip file
zip_file_path = '/content/dataset.zip'
2
# Destination folder to unzip the .zip file
extract_to = '/content/'

# If the target folder does not exist, create it
os.makedirs(extract_to, exist_ok=True)

#Here we are extracting the .zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to)

# Check the file structure
for root, dirs, files in os.walk(extract_to):
    for filename in files:
        print(os.path.join(root, filename))
# Out:
# /content/dataset.zip
# /content/.config/active_config
# /content/.config/.last_update_check.json
# /content/.config/.last_opt_in_prompt.yaml
# /content/.config/gce
# /content/.config/.last_survey_prompt.yaml
# /content/.config/default_configs.db
# /content/.config/config_sentinel
# /content/.config/logs/2024.06.20/18.45.34.766844.log
# /content/.config/logs/2024.06.20/18.44.51.925580.log
# /content/.config/logs/2024.06.20/18.45.46.131261.log
# /content/.config/logs/2024.06.20/18.45.16.088421.log
# /content/.config/logs/2024.06.20/18.45.46.750529.log
# /content/.config/logs/2024.06.20/18.45.26.499835.log
# /content/.config/configurations/config_default
# /content/dataset/test.csv
# /content/dataset/shine/shine230.jpg
# /content/dataset/shine/shine39.jpg
# /content/dataset/shine/shine95.jpg
# /content/dataset/shine/shine147.jpg
# /content/dataset/shine/shine179.jpg
# /content/dataset/shine/shine59.jpg
# /content/dataset/shine/shine231.jpg
# /content/dataset/shine/shine104.jpg
# /content/dataset/shine/shine71.jpg
# /content/dataset/shine/shine103.jpg
# /content/dataset/shine/shine92.jpg
# /content/dataset/shine/shine1.jpg
# /content/dataset/shine/shine223.jpg
# /content/dataset/shine/shine91.jpg
# /content/dataset/shine/shine63.jpg
# /content/dataset/shine/shine34.jpg
# /content/dataset/shine/shine98.jpg
# /content/dataset/shine/shine4.jpg
# /content/dataset/shine/shine140.jpg
# /content/dataset/shine/shine16.jpg
# /content/dataset/shine/shine240.jpg
# /content/dataset/shine/shine135.jpg
# /content/dataset/shine/shine125.jpg
# /content/dataset/shine/shine78.jpg
# /content/dataset/shine/shine88.jpg
# /content/dataset/shine/shine169.jpg
# /content/dataset/shine/shine31.jpg
# /content/dataset/shine/shine85.jpg
# /content/dataset/shine/shine128.jpg
# /content/dataset/shine/shine183.jpg
# /content/dataset/shine/shine242.jpg
# /content/dataset/shine/shine42.jpg
# /content/dataset/shine/shine45.jpg
# /content/dataset/shine/shine205.jpg
# /content/dataset/shine/shine143.jpg
# /content/dataset/shine/shine138.jpg
# /content/dataset/shine/shine111.jpg
# /content/dataset/shine/shine131.jpg
# /content/dataset/shine/shine206.jpg
# /content/dataset/shine/shine244.jpg
# /content/dataset/shine/shine67.jpg
# /content/dataset/shine/shine190.jpg
# /content/dataset/shine/shine38.jpg
# /content/dataset/shine/shine96.jpg
# /content/dataset/shine/shine115.jpg
# /content/dataset/shine/shine65.jpg
# /content/dataset/shine/shine152.jpg
# /content/dataset/shine/shine114.jpg
# /content/dataset/shine/shine235.jpg
# /content/dataset/shine/shine62.jpg
# /content/dataset/shine/shine119.jpg
# /content/dataset/shine/shine134.jpg
# /content/dataset/shine/shine83.jpg
# /content/dataset/shine/shine141.jpg
# /content/dataset/shine/shine229.jpg
# /content/dataset/shine/shine228.jpg
# /content/dataset/shine/shine33.jpg
# /content/dataset/shine/shine227.jpg
# /content/dataset/shine/shine218.jpg
# /content/dataset/shine/shine77.jpg
# /content/dataset/shine/shine142.jpg
# /content/dataset/shine/shine149.jpg
# /content/dataset/shine/shine58.jpg
# /content/dataset/shine/shine197.jpg
# /content/dataset/shine/shine68.jpg
# /content/dataset/shine/shine188.jpg
# /content/dataset/shine/shine137.jpg
# /content/dataset/shine/shine178.jpg
# /content/dataset/shine/shine28.jpg
# /content/dataset/shine/shine191.jpg
# /content/dataset/shine/shine110.jpg
# /content/dataset/shine/shine187.jpg
# /content/dataset/shine/shine61.jpg
# /content/dataset/shine/shine167.jpg
# /content/dataset/shine/shine214.jpg
# /content/dataset/shine/shine84.jpg
# /content/dataset/shine/shine89.jpg
# /content/dataset/shine/shine64.jpg
# /content/dataset/shine/shine43.jpg
# /content/dataset/shine/shine8.jpg
# /content/dataset/shine/shine241.jpg
# /content/dataset/shine/shine116.jpg
# /content/dataset/shine/shine11.jpg
# /content/dataset/shine/shine32.jpg
# /content/dataset/shine/shine106.jpg
# /content/dataset/shine/shine217.jpg
# /content/dataset/shine/shine151.jpg
# /content/dataset/shine/shine247.jpg
# /content/dataset/shine/shine87.jpg
# /content/dataset/shine/shine176.jpg
# /content/dataset/shine/shine27.jpg
# /content/dataset/shine/shine48.jpg
# /content/dataset/shine/shine180.jpg
# /content/dataset/shine/shine133.jpg
# /content/dataset/shine/shine246.jpg
# /content/dataset/shine/shine80.jpg
# /content/dataset/shine/shine204.jpg
# /content/dataset/shine/shine2.jpg
# /content/dataset/shine/shine144.jpg
# /content/dataset/shine/shine120.jpg
# /content/dataset/shine/shine53.jpg
# /content/dataset/shine/shine163.jpg
# /content/dataset/shine/shine132.jpg
# /content/dataset/shine/shine221.jpg
# /content/dataset/shine/shine166.jpg
# /content/dataset/shine/shine74.jpg
# /content/dataset/shine/shine252.jpg
# /content/dataset/shine/shine13.jpg
# /content/dataset/shine/shine216.jpg
# /content/dataset/shine/shine139.jpg
# /content/dataset/shine/shine232.jpg
# /content/dataset/shine/shine238.jpg
# /content/dataset/shine/shine200.jpg
# /content/dataset/shine/shine237.jpg
# /content/dataset/shine/shine161.jpg
# /content/dataset/shine/shine210.jpg
# /content/dataset/shine/shine25.jpg
# /content/dataset/shine/shine109.jpg
# /content/dataset/shine/shine121.jpg
# /content/dataset/shine/shine236.jpg
# /content/dataset/shine/shine182.jpg
# /content/dataset/shine/shine46.jpg
# /content/dataset/shine/shine50.jpg
# /content/dataset/shine/shine101.jpg
# /content/dataset/shine/shine185.jpg
# /content/dataset/shine/shine207.jpg
# /content/dataset/shine/shine203.jpg
# /content/dataset/shine/shine66.jpg
# /content/dataset/shine/shine19.jpg
# /content/dataset/shine/shine225.jpg
# /content/dataset/shine/shine76.jpg
# /content/dataset/shine/shine172.jpg
# /content/dataset/shine/shine248.jpg
# /content/dataset/shine/shine153.jpg
# /content/dataset/shine/shine211.jpg
# /content/dataset/shine/shine69.jpg
# /content/dataset/shine/shine47.jpg
# /content/dataset/shine/shine100.jpg
# /content/dataset/shine/shine82.jpg
# /content/dataset/shine/shine93.jpg
# /content/dataset/shine/shine156.jpg
# /content/dataset/shine/shine54.jpg
# /content/dataset/shine/shine215.jpg
# /content/dataset/shine/shine224.jpg
# /content/dataset/shine/shine164.jpg
# /content/dataset/shine/shine239.jpg
# /content/dataset/shine/shine209.jpg
# /content/dataset/shine/shine26.jpg
# /content/dataset/shine/shine196.jpg
# /content/dataset/shine/shine94.jpg
# /content/dataset/shine/shine171.jpg
# /content/dataset/shine/shine49.jpg
# /content/dataset/shine/shine249.jpg
# /content/dataset/shine/shine20.jpg
# /content/dataset/shine/shine154.jpg
# /content/dataset/shine/shine22.jpg
# /content/dataset/shine/shine51.jpg
# /content/dataset/shine/shine165.jpg
# /content/dataset/shine/shine44.jpg
# /content/dataset/shine/shine168.jpg
# /content/dataset/shine/shine186.jpg
# /content/dataset/shine/shine234.jpg
# /content/dataset/shine/shine17.jpg
# /content/dataset/shine/shine70.jpg
# /content/dataset/shine/shine212.jpg
# /content/dataset/shine/shine226.jpg
# /content/dataset/shine/shine21.jpg
# /content/dataset/shine/shine35.jpg
# /content/dataset/shine/shine75.jpg
# /content/dataset/shine/shine170.jpg
# /content/dataset/shine/shine145.jpg
# /content/dataset/shine/shine73.jpg
# /content/dataset/shine/shine102.jpg
# /content/dataset/shine/shine127.jpg
# /content/dataset/shine/shine60.jpg
# /content/dataset/shine/shine201.jpg
# /content/dataset/shine/shine56.jpg
# /content/dataset/shine/shine126.jpg
# /content/dataset/shine/shine130.jpg
# /content/dataset/shine/shine192.jpg
# /content/dataset/shine/shine123.jpg
# /content/dataset/shine/shine118.jpg
# /content/dataset/shine/shine57.jpg
# /content/dataset/shine/shine150.jpg
# /content/dataset/shine/shine195.jpg
# /content/dataset/shine/shine157.jpg
# /content/dataset/shine/shine219.jpg
# /content/dataset/shine/shine162.jpg
# /content/dataset/shine/shine117.jpg
# /content/dataset/shine/shine81.jpg
# /content/dataset/shine/shine160.jpg
# /content/dataset/shine/shine55.jpg
# /content/dataset/shine/shine155.jpg
# /content/dataset/shine/shine3.jpg
# /content/dataset/shine/shine198.jpg
# /content/dataset/shine/shine12.jpg
# /content/dataset/shine/shine122.jpg
# /content/dataset/shine/shine148.jpg
# /content/dataset/shine/shine14.jpg
# /content/dataset/shine/shine208.jpg
# /content/dataset/shine/shine113.jpg
# /content/dataset/shine/shine173.jpg
# /content/dataset/shine/shine40.jpg
# /content/dataset/shine/shine9.jpg
# /content/dataset/shine/shine222.jpg
# /content/dataset/shine/shine158.jpg
# /content/dataset/shine/shine10.jpg
# /content/dataset/shine/shine177.jpg
# /content/dataset/shine/shine175.jpg
# /content/dataset/shine/shine189.jpg
# /content/dataset/shine/shine29.jpg
# /content/dataset/shine/shine213.jpg
# /content/dataset/shine/shine18.jpg
# /content/dataset/shine/shine243.jpg
# /content/dataset/shine/shine193.jpg
# /content/dataset/shine/shine194.jpg
# /content/dataset/shine/shine146.jpg
# /content/dataset/shine/shine24.jpg
# /content/dataset/shine/shine23.jpg
# /content/dataset/shine/shine7.jpg
# /content/dataset/shine/shine174.jpg
# /content/dataset/shine/shine6.jpg
# /content/dataset/shine/shine86.jpg
# /content/dataset/shine/shine15.jpg
# /content/dataset/shine/shine90.jpg
# /content/dataset/shine/shine245.jpg
# /content/dataset/shine/shine99.jpg
# /content/dataset/shine/shine97.jpg
# /content/dataset/shine/shine129.jpg
# /content/dataset/shine/shine181.jpg
# /content/dataset/shine/shine36.jpg
# /content/dataset/shine/shine124.jpg
# /content/dataset/shine/shine72.jpg
# /content/dataset/shine/shine202.jpg
# /content/dataset/shine/shine105.jpg
# /content/dataset/shine/shine184.jpg
# /content/dataset/shine/shine41.jpg
# /content/dataset/shine/shine159.jpg
# /content/dataset/shine/shine108.jpg
# /content/dataset/shine/shine233.jpg
# /content/dataset/shine/shine79.jpg
# /content/dataset/shine/shine52.jpg
# /content/dataset/shine/shine30.jpg
# /content/dataset/shine/shine112.jpg
# /content/dataset/shine/shine136.jpg
# /content/dataset/shine/shine107.jpg
# /content/dataset/shine/shine5.jpg
# /content/dataset/shine/shine220.jpg
# /content/dataset/shine/shine37.jpg
# /content/dataset/shine/shine199.jpg
# /content/dataset/rainy/rain75.jpg
# /content/dataset/rainy/rain148.jpg
# /content/dataset/rainy/rain166.jpg
# /content/dataset/rainy/rain70.jpg
# /content/dataset/rainy/rain133.jpg
# /content/dataset/rainy/rain204.jpg
# /content/dataset/rainy/rain37.jpg
# /content/dataset/rainy/rain251.jpg
# /content/dataset/rainy/rain139.jpg
# /content/dataset/rainy/rain287.jpg
# /content/dataset/rainy/rain174.jpg
# /content/dataset/rainy/rain93.jpg
# /content/dataset/rainy/rain292.jpg
# /content/dataset/rainy/rain155.jpg
# /content/dataset/rainy/rain24.jpeg
# /content/dataset/rainy/rain167.jpg
# /content/dataset/rainy/rain272.jpg
# /content/dataset/rainy/rain44.jpg
# /content/dataset/rainy/rain232.jpg
# /content/dataset/rainy/rain286.jpg
# /content/dataset/rainy/rain171.jpg
# /content/dataset/rainy/rain71.jpg
# /content/dataset/rainy/rain169.jpg
# /content/dataset/rainy/rain152.jpg
# /content/dataset/rainy/rain58.jpg
# /content/dataset/rainy/rain32.jpg
# /content/dataset/rainy/rain275.jpg
# /content/dataset/rainy/rain242.jpg
# /content/dataset/rainy/rain277.jpg
# /content/dataset/rainy/rain276.jpg
# /content/dataset/rainy/rain162.jpg
# /content/dataset/rainy/rain18.jpg
# /content/dataset/rainy/rain227.jpeg
# /content/dataset/rainy/rain52.jpg
# /content/dataset/rainy/rain170.jpg
# /content/dataset/rainy/rain173.jpg
# /content/dataset/rainy/rain206.jpg
# /content/dataset/rainy/rain107.jpg
# /content/dataset/rainy/rain284.jpg
# /content/dataset/rainy/rain194.jpg
# /content/dataset/rainy/rain89.jpg
# /content/dataset/rainy/rain154.jpg
# /content/dataset/rainy/rain200.jpg
# /content/dataset/rainy/rain254.jpg
# /content/dataset/rainy/rain106.jpg
# /content/dataset/rainy/rain60.jpg
# /content/dataset/rainy/rain145.jpg
# /content/dataset/rainy/rain57.jpg
# /content/dataset/rainy/rain296.jpg
# /content/dataset/rainy/rain43.jpg
# /content/dataset/rainy/rain189.jpg
# /content/dataset/rainy/rain141.jpg
# /content/dataset/rainy/rain98.jpg
# /content/dataset/rainy/rain237.jpg
# /content/dataset/rainy/rain295.jpg
# /content/dataset/rainy/rain236.jpg
# /content/dataset/rainy/rain244.jpg
# /content/dataset/rainy/rain96.jpg
# /content/dataset/rainy/rain86.jpg
# /content/dataset/rainy/rain192.jpg
# /content/dataset/rainy/rain88.jpg
# /content/dataset/rainy/rain14.jpg
# /content/dataset/rainy/rain165.jpg
# /content/dataset/rainy/rain142.jpg
# /content/dataset/rainy/rain49.jpg
# /content/dataset/rainy/rain180.jpg
# /content/dataset/rainy/rain271.jpg
# /content/dataset/rainy/rain79.jpg
# /content/dataset/rainy/rain25.jpg
# /content/dataset/rainy/rain29.jpg
# /content/dataset/rainy/rain48.jpg
# /content/dataset/rainy/rain117.jpg
# /content/dataset/rainy/rain270.jpg
# /content/dataset/rainy/rain191.jpg
# /content/dataset/rainy/rain158.jpg
# /content/dataset/rainy/rain208.jpg
# /content/dataset/rainy/rain28.jpg
# /content/dataset/rainy/rain84.jpg
# /content/dataset/rainy/rain216.jpeg
# /content/dataset/rainy/rain78.jpg
# /content/dataset/rainy/rain207.jpeg
# /content/dataset/rainy/rain19.jpg
# /content/dataset/rainy/rain233.jpg
# /content/dataset/rainy/rain103.jpg
# /content/dataset/rainy/rain7.jpg
# /content/dataset/rainy/rain76.jpg
# /content/dataset/rainy/rain122.jpg
# /content/dataset/rainy/rain178.jpg
# /content/dataset/rainy/rain195.jpg
# /content/dataset/rainy/rain50.jpg
# /content/dataset/rainy/rain255.jpg
# /content/dataset/rainy/rain215.jpg
# /content/dataset/rainy/rain186.jpg
# /content/dataset/rainy/rain213.jpg
# /content/dataset/rainy/rain184.jpg
# /content/dataset/rainy/rain224.jpg
# /content/dataset/rainy/rain41.jpg
# /content/dataset/rainy/rain67.jpg
# /content/dataset/rainy/rain100.jpg
# /content/dataset/rainy/rain176.jpg
# /content/dataset/rainy/rain238.jpg
# /content/dataset/rainy/rain218.jpeg
# /content/dataset/rainy/rain56.jpg
# /content/dataset/rainy/rain281.jpg
# /content/dataset/rainy/rain249.jpg
# /content/dataset/rainy/rain33.jpg
# /content/dataset/rainy/rain190.jpg
# /content/dataset/rainy/rain53.jpg
# /content/dataset/rainy/rain54.jpg
# /content/dataset/rainy/rain149.jpg
# /content/dataset/rainy/rain197.jpg
# /content/dataset/rainy/rain27.jpg
# /content/dataset/rainy/rain157.jpg
# /content/dataset/rainy/rain264.jpg
# /content/dataset/rainy/rain297.jpg
# /content/dataset/rainy/rain198.jpg
# /content/dataset/rainy/rain20.jpg
# /content/dataset/rainy/rain59.jpg
# /content/dataset/rainy/rain101.jpg
# /content/dataset/rainy/rain161.jpg
# /content/dataset/rainy/rain243.jpg
# /content/dataset/rainy/rain95.jpg
# /content/dataset/rainy/rain80.jpg
# /content/dataset/rainy/rain220.jpeg
# /content/dataset/rainy/rain136.jpg
# /content/dataset/rainy/rain258.jpg
# /content/dataset/rainy/rain16.jpg
# /content/dataset/rainy/rain118.jpg
# /content/dataset/rainy/rain105.jpg
# /content/dataset/rainy/rain3.jpg
# /content/dataset/rainy/rain177.jpg
# /content/dataset/rainy/rain114.jpg
# /content/dataset/rainy/rain83.jpg
# /content/dataset/rainy/rain12.jpg
# /content/dataset/rainy/rain10.jpg
# /content/dataset/rainy/rain138.jpg
# /content/dataset/rainy/rain151.jpg
# /content/dataset/rainy/rain137.jpg
# /content/dataset/rainy/rain268.jpg
# /content/dataset/rainy/rain159.jpg
# /content/dataset/rainy/rain61.jpg
# /content/dataset/rainy/rain283.jpg
# /content/dataset/rainy/rain163.jpg
# /content/dataset/rainy/rain17.jpg
# /content/dataset/rainy/rain269.jpg
# /content/dataset/rainy/rain13.jpg
# /content/dataset/rainy/rain202.jpg
# /content/dataset/rainy/rain147.jpg
# /content/dataset/rainy/rain120.jpg
# /content/dataset/rainy/rain259.jpg
# /content/dataset/rainy/rain196.jpg
# /content/dataset/rainy/rain91.jpg
# /content/dataset/rainy/rain209.jpg
# /content/dataset/rainy/rain185.jpg
# /content/dataset/rainy/rain187.jpg
# /content/dataset/rainy/rain245.jpg
# /content/dataset/rainy/rain68.jpg
# /content/dataset/rainy/rain153.jpg
# /content/dataset/rainy/rain188.jpg
# /content/dataset/rainy/rain34.jpg
# /content/dataset/rainy/rain15.jpg
# /content/dataset/rainy/rain217.jpeg
# /content/dataset/rainy/rain134.jpg
# /content/dataset/rainy/rain26.jpg
# /content/dataset/rainy/rain87.jpg
# /content/dataset/rainy/rain22.jpeg
# /content/dataset/rainy/rain246.jpg
# /content/dataset/rainy/rain280.jpg
# /content/dataset/rainy/rain125.jpg
# /content/dataset/rainy/rain62.jpg
# /content/dataset/rainy/rain116.jpg
# /content/dataset/rainy/rain90.jpg
# /content/dataset/rainy/rain252.jpg
# /content/dataset/rainy/rain273.jpg
# /content/dataset/rainy/rain30.jpg
# /content/dataset/rainy/rain289.jpg
# /content/dataset/rainy/rain108.jpg
# /content/dataset/rainy/rain55.jpg
# /content/dataset/rainy/rain248.jpg
# /content/dataset/rainy/rain290.jpg
# /content/dataset/rainy/rain47.jpg
# /content/dataset/rainy/rain240.jpg
# /content/dataset/rainy/rain99.jpg
# /content/dataset/rainy/rain11.jpg
# /content/dataset/rainy/rain221.jpeg
# /content/dataset/rainy/rain143.jpg
# /content/dataset/rainy/rain299.jpg
# /content/dataset/rainy/rain77.jpg
# /content/dataset/rainy/rain181.jpg
# /content/dataset/rainy/rain4.jpg
# /content/dataset/rainy/rain2.jpg
# /content/dataset/rainy/rain112.jpg
# /content/dataset/rainy/rain64.jpg
# /content/dataset/rainy/rain193.jpg
# /content/dataset/rainy/rain266.jpg
# /content/dataset/rainy/rain144.jpg
# /content/dataset/rainy/rain182.jpg
# /content/dataset/rainy/rain104.jpg
# /content/dataset/rainy/rain85.jpg
# /content/dataset/rainy/rain128.jpg
# /content/dataset/rainy/rain285.jpg
# /content/dataset/rainy/rain300.jpg
# /content/dataset/rainy/rain146.jpg
# /content/dataset/rainy/rain253.jpg
# /content/dataset/rainy/rain179.jpg
# /content/dataset/rainy/rain219.jpeg
# /content/dataset/rainy/rain113.jpg
# /content/dataset/rainy/rain282.jpg
# /content/dataset/rainy/rain225.jpeg
# /content/dataset/rainy/rain239.jpg
# /content/dataset/rainy/rain35.jpg
# /content/dataset/rainy/rain241.jpg
# /content/dataset/rainy/rain8.jpg
# /content/dataset/rainy/rain164.jpg
# /content/dataset/rainy/rain261.jpg
# /content/dataset/rainy/rain262.jpg
# /content/dataset/rainy/rain257.jpg
# /content/dataset/rainy/rain23.jpg
# /content/dataset/rainy/rain223.jpeg
# /content/dataset/rainy/rain121.jpg
# /content/dataset/rainy/rain135.jpg
# /content/dataset/rainy/rain31.jpg
# /content/dataset/rainy/rain250.jpg
# /content/dataset/rainy/rain260.jpg
# /content/dataset/rainy/rain5.jpg
# /content/dataset/rainy/rain298.jpg
# /content/dataset/rainy/rain63.jpg
# /content/dataset/rainy/rain119.jpg
# /content/dataset/rainy/rain274.jpg
# /content/dataset/rainy/rain110.jpg
# /content/dataset/rainy/rain72.jpg
# /content/dataset/rainy/rain74.jpg
# /content/dataset/rainy/rain6.jpg
# /content/dataset/rainy/rain201.jpg
# /content/dataset/rainy/rain40.jpg
# /content/dataset/rainy/rain131.jpg
# /content/dataset/rainy/rain82.jpg
# /content/dataset/rainy/rain129.jpg
# /content/dataset/rainy/rain291.jpg
# /content/dataset/rainy/rain183.jpg
# /content/dataset/rainy/rain199.jpg
# /content/dataset/rainy/rain247.jpg
# /content/dataset/rainy/rain36.jpg
# /content/dataset/rainy/rain234.jpg
# /content/dataset/rainy/rain150.jpg
# /content/dataset/rainy/rain278.jpg
# /content/dataset/rainy/rain66.jpg
# /content/dataset/rainy/rain294.jpg
# /content/dataset/rainy/rain263.jpg
# /content/dataset/rainy/rain45.jpg
# /content/dataset/rainy/rain230.jpeg
# /content/dataset/rainy/rain9.jpg
# /content/dataset/rainy/rain51.jpg
# /content/dataset/rainy/rain279.jpg
# /content/dataset/rainy/rain211.jpg
# /content/dataset/rainy/rain42.jpg
# /content/dataset/rainy/rain235.jpg
# /content/dataset/rainy/rain226.jpeg
# /content/dataset/rainy/rain111.jpg
# /content/dataset/rainy/rain21.jpg
# /content/dataset/rainy/rain1.jpg
# /content/dataset/rainy/rain115.jpg
# /content/dataset/rainy/rain130.jpg
# /content/dataset/rainy/rain38.jpg
# /content/dataset/rainy/rain175.jpg
# /content/dataset/rainy/rain222.jpeg
# /content/dataset/rainy/rain140.jpg
# /content/dataset/rainy/rain126.jpg
# /content/dataset/rainy/rain94.jpg
# /content/dataset/rainy/rain73.jpg
# /content/dataset/rainy/rain205.jpg
# /content/dataset/rainy/rain160.jpg
# /content/dataset/rainy/rain81.jpg
# /content/dataset/rainy/rain203.jpg
# /content/dataset/rainy/rain156.jpg
# /content/dataset/rainy/rain132.jpg
# /content/dataset/rainy/rain46.jpg
# /content/dataset/rainy/rain109.jpg
# /content/dataset/rainy/rain92.jpg
# /content/dataset/rainy/rain123.jpg
# /content/dataset/rainy/rain65.jpg
# /content/dataset/rainy/rain172.jpg
# /content/dataset/rainy/rain39.jpg
# /content/dataset/rainy/rain267.jpg
# /content/dataset/rainy/rain124.jpg
# /content/dataset/rainy/rain229.jpeg
# /content/dataset/rainy/rain288.jpg
# /content/dataset/rainy/rain265.jpg
# /content/dataset/rainy/rain212.jpg
# /content/dataset/rainy/rain214.jpg
# /content/dataset/rainy/rain69.jpg
# /content/dataset/rainy/rain231.jpeg
# /content/dataset/rainy/rain97.jpg
# /content/dataset/rainy/rain127.jpg
# /content/dataset/rainy/rain168.jpg
# /content/dataset/rainy/rain293.jpg
# /content/dataset/rainy/rain256.jpg
# /content/dataset/rainy/rain228.jpg
# /content/dataset/rainy/rain102.jpg
# /content/dataset/rainy/rain210.jpg
# /content/dataset/foggy/foggy74.jpg
# /content/dataset/foggy/foggy249.jpg
# /content/dataset/foggy/foggy23.jpg
# /content/dataset/foggy/foggy175.jpg
# /content/dataset/foggy/foggy1.jpg
# /content/dataset/foggy/foggy119.jpg
# /content/dataset/foggy/foggy4.jpeg
# /content/dataset/foggy/foggy100.jpg
# /content/dataset/foggy/foggy244.jpg
# /content/dataset/foggy/foggy81.jpg
# /content/dataset/foggy/foggy63.jpg
# /content/dataset/foggy/foggy75.jpg
# /content/dataset/foggy/foggy228.jpg
# /content/dataset/foggy/foggy196.jpg
# /content/dataset/foggy/foggy275.jpg
# /content/dataset/foggy/foggy95.jpg
# /content/dataset/foggy/foggy19.jpg
# /content/dataset/foggy/foggy76.jpg
# /content/dataset/foggy/foggy141.jpg
# /content/dataset/foggy/foggy189.jpg
# /content/dataset/foggy/foggy188.jpg
# /content/dataset/foggy/foggy38.jpg
# /content/dataset/foggy/foggy158.jpg
# /content/dataset/foggy/foggy6.jpg
# /content/dataset/foggy/foggy68.jpg
# /content/dataset/foggy/foggy60.jpg
# /content/dataset/foggy/foggy285.jpg
# /content/dataset/foggy/foggy291.jpg
# /content/dataset/foggy/foggy171.jpg
# /content/dataset/foggy/foggy206.jpg
# /content/dataset/foggy/foggy72.jpg
# /content/dataset/foggy/foggy261.jpg
# /content/dataset/foggy/foggy286.jpg
# /content/dataset/foggy/foggy55.jpg
# /content/dataset/foggy/foggy300.jpg
# /content/dataset/foggy/foggy137.jpg
# /content/dataset/foggy/foggy226.jpg
# /content/dataset/foggy/foggy283.jpg
# /content/dataset/foggy/foggy57.jpg
# /content/dataset/foggy/foggy42.jpg
# /content/dataset/foggy/foggy191.jpg
# /content/dataset/foggy/foggy108.jpg
# /content/dataset/foggy/foggy239.jpg
# /content/dataset/foggy/foggy103.jpg
# /content/dataset/foggy/foggy263.jpg
# /content/dataset/foggy/foggy190.jpg
# /content/dataset/foggy/foggy177.jpg
# /content/dataset/foggy/foggy168.jpg
# /content/dataset/foggy/foggy273.jpg
# /content/dataset/foggy/foggy292.jpg
# /content/dataset/foggy/foggy97.jpg
# /content/dataset/foggy/foggy50.jpg
# /content/dataset/foggy/foggy154.jpg
# /content/dataset/foggy/foggy136.jpg
# /content/dataset/foggy/foggy257.jpg
# /content/dataset/foggy/foggy246.jpg
# /content/dataset/foggy/foggy176.jpg
# /content/dataset/foggy/foggy69.jpg
# /content/dataset/foggy/foggy90.jpg
# /content/dataset/foggy/foggy24.jpg
# /content/dataset/foggy/foggy221.jpeg
# /content/dataset/foggy/foggy13.jpg
# /content/dataset/foggy/foggy174.jpg
# /content/dataset/foggy/foggy27.jpg
# /content/dataset/foggy/foggy295.jpg
# /content/dataset/foggy/foggy112.jpg
# /content/dataset/foggy/foggy209.jpeg
# /content/dataset/foggy/foggy253.jpg
# /content/dataset/foggy/foggy287.jpg
# /content/dataset/foggy/foggy131.jpg
# /content/dataset/foggy/foggy147.jpg
# /content/dataset/foggy/foggy139.jpg
# /content/dataset/foggy/foggy123.jpg
# /content/dataset/foggy/foggy279.jpg
# /content/dataset/foggy/foggy205.jpeg
# /content/dataset/foggy/foggy135.jpg
# /content/dataset/foggy/foggy198.jpg
# /content/dataset/foggy/foggy96.jpg
# /content/dataset/foggy/foggy52.jpg
# /content/dataset/foggy/foggy169.jpg
# /content/dataset/foggy/foggy111.jpg
# /content/dataset/foggy/foggy3.jpeg
# /content/dataset/foggy/foggy192.jpg
# /content/dataset/foggy/foggy26.jpg
# /content/dataset/foggy/foggy240.jpg
# /content/dataset/foggy/foggy16.jpg
# /content/dataset/foggy/foggy258.jpg
# /content/dataset/foggy/foggy212.jpeg
# /content/dataset/foggy/foggy22.jpg
# /content/dataset/foggy/foggy29.jpg
# /content/dataset/foggy/foggy34.jpg
# /content/dataset/foggy/foggy267.jpg
# /content/dataset/foggy/foggy157.jpg
# /content/dataset/foggy/foggy202.jpg
# /content/dataset/foggy/foggy194.jpg
# /content/dataset/foggy/foggy241.jpg
# /content/dataset/foggy/foggy36.jpg
# /content/dataset/foggy/foggy25.jpg
# /content/dataset/foggy/foggy2.jpg
# /content/dataset/foggy/foggy151.jpg
# /content/dataset/foggy/foggy203.jpeg
# /content/dataset/foggy/foggy227.jpg
# /content/dataset/foggy/foggy17.jpg
# /content/dataset/foggy/foggy166.jpg
# /content/dataset/foggy/foggy126.jpg
# /content/dataset/foggy/foggy62.jpg
# /content/dataset/foggy/foggy127.jpg
# /content/dataset/foggy/foggy278.jpg
# /content/dataset/foggy/foggy207.jpeg
# /content/dataset/foggy/foggy210.jpeg
# /content/dataset/foggy/foggy235.jpg
# /content/dataset/foggy/foggy102.jpg
# /content/dataset/foggy/foggy61.jpg
# /content/dataset/foggy/foggy56.jpg
# /content/dataset/foggy/foggy150.jpg
# /content/dataset/foggy/foggy256.jpg
# /content/dataset/foggy/foggy247.jpg
# /content/dataset/foggy/foggy41.jpg
# /content/dataset/foggy/foggy116.jpg
# /content/dataset/foggy/foggy98.jpg
# /content/dataset/foggy/foggy229.jpg
# /content/dataset/foggy/foggy217.jpeg
# /content/dataset/foggy/foggy155.jpg
# /content/dataset/foggy/foggy225.jpg
# /content/dataset/foggy/foggy259.jpg
# /content/dataset/foggy/foggy186.jpg
# /content/dataset/foggy/foggy161.jpg
# /content/dataset/foggy/foggy107.jpg
# /content/dataset/foggy/foggy281.jpg
# /content/dataset/foggy/foggy214.jpg
# /content/dataset/foggy/foggy105.jpg
# /content/dataset/foggy/foggy284.jpg
# /content/dataset/foggy/foggy140.jpg
# /content/dataset/foggy/foggy54.jpg
# /content/dataset/foggy/foggy114.jpg
# /content/dataset/foggy/foggy142.jpg
# /content/dataset/foggy/foggy129.jpg
# /content/dataset/foggy/foggy242.jpg
# /content/dataset/foggy/foggy66.jpg
# /content/dataset/foggy/foggy86.jpg
# /content/dataset/foggy/foggy222.jpg
# /content/dataset/foggy/foggy163.jpg
# /content/dataset/foggy/foggy101.jpg
# /content/dataset/foggy/foggy20.jpg
# /content/dataset/foggy/foggy220.jpeg
# /content/dataset/foggy/foggy73.jpg
# /content/dataset/foggy/foggy170.jpg
# /content/dataset/foggy/foggy109.jpg
# /content/dataset/foggy/foggy11.jpg
# /content/dataset/foggy/foggy219.jpg
# /content/dataset/foggy/foggy148.jpg
# /content/dataset/foggy/foggy121.jpg
# /content/dataset/foggy/foggy237.jpg
# /content/dataset/foggy/foggy282.jpg
# /content/dataset/foggy/foggy213.jpg
# /content/dataset/foggy/foggy167.jpg
# /content/dataset/foggy/foggy87.jpg
# /content/dataset/foggy/foggy264.jpg
# /content/dataset/foggy/foggy133.jpg
# /content/dataset/foggy/foggy110.jpg
# /content/dataset/foggy/foggy14.jpg
# /content/dataset/foggy/foggy118.jpg
# /content/dataset/foggy/foggy15.jpg
# /content/dataset/foggy/foggy224.jpg
# /content/dataset/foggy/foggy67.jpg
# /content/dataset/foggy/foggy32.jpg
# /content/dataset/foggy/foggy145.jpg
# /content/dataset/foggy/foggy28.jpg
# /content/dataset/foggy/foggy130.jpg
# /content/dataset/foggy/foggy80.jpg
# /content/dataset/foggy/foggy45.jpg
# /content/dataset/foggy/foggy248.jpg
# /content/dataset/foggy/foggy236.jpg
# /content/dataset/foggy/foggy94.jpg
# /content/dataset/foggy/foggy39.jpg
# /content/dataset/foggy/foggy124.jpg
# /content/dataset/foggy/foggy296.jpg
# /content/dataset/foggy/foggy58.jpg
# /content/dataset/foggy/foggy12.jpg
# /content/dataset/foggy/foggy8.jpg
# /content/dataset/foggy/foggy201.jpg
# /content/dataset/foggy/foggy84.jpg
# /content/dataset/foggy/foggy293.jpg
# /content/dataset/foggy/foggy48.jpg
# /content/dataset/foggy/foggy270.jpg
# /content/dataset/foggy/foggy164.jpg
# /content/dataset/foggy/foggy250.jpg
# /content/dataset/foggy/foggy144.jpg
# /content/dataset/foggy/foggy7.jpg
# /content/dataset/foggy/foggy276.jpg
# /content/dataset/foggy/foggy91.jpg
# /content/dataset/foggy/foggy280.jpg
# /content/dataset/foggy/foggy40.jpg
# /content/dataset/foggy/foggy290.jpg
# /content/dataset/foggy/foggy89.jpg
# /content/dataset/foggy/foggy44.jpg
# /content/dataset/foggy/foggy59.jpg
# /content/dataset/foggy/foggy37.jpg
# /content/dataset/foggy/foggy146.jpg
# /content/dataset/foggy/foggy10.jpg
# /content/dataset/foggy/foggy162.jpg
# /content/dataset/foggy/foggy197.jpg
# /content/dataset/foggy/foggy30.jpg
# /content/dataset/foggy/foggy277.jpg
# /content/dataset/foggy/foggy138.jpg
# /content/dataset/foggy/foggy165.jpg
# /content/dataset/foggy/foggy83.jpg
# /content/dataset/foggy/foggy187.jpg
# /content/dataset/foggy/foggy231.jpg
# /content/dataset/foggy/foggy159.jpg
# /content/dataset/foggy/foggy268.jpg
# /content/dataset/foggy/foggy43.jpg
# /content/dataset/foggy/foggy47.jpg
# /content/dataset/foggy/foggy181.jpg
# /content/dataset/foggy/foggy77.jpg
# /content/dataset/foggy/foggy254.jpg
# /content/dataset/foggy/foggy125.jpg
# /content/dataset/foggy/foggy271.jpg
# /content/dataset/foggy/foggy85.jpg
# /content/dataset/foggy/foggy182.jpg
# /content/dataset/foggy/foggy35.jpg
# /content/dataset/foggy/foggy274.jpg
# /content/dataset/foggy/foggy298.jpg
# /content/dataset/foggy/foggy199.jpg
# /content/dataset/foggy/foggy49.jpg
# /content/dataset/foggy/foggy132.jpg
# /content/dataset/foggy/foggy215.jpeg
# /content/dataset/foggy/foggy211.jpeg
# /content/dataset/foggy/foggy251.jpg
# /content/dataset/foggy/foggy33.jpg
# /content/dataset/foggy/foggy289.jpg
# /content/dataset/foggy/foggy79.jpg
# /content/dataset/foggy/foggy216.jpeg
# /content/dataset/foggy/foggy184.jpg
# /content/dataset/foggy/foggy31.jpg
# /content/dataset/foggy/foggy233.jpg
# /content/dataset/foggy/foggy204.jpg
# /content/dataset/foggy/foggy200.jpg
# /content/dataset/foggy/foggy113.jpg
# /content/dataset/foggy/foggy115.jpg
# /content/dataset/foggy/foggy70.jpg
# /content/dataset/foggy/foggy104.jpg
# /content/dataset/foggy/foggy78.jpg
# /content/dataset/foggy/foggy265.jpg
# /content/dataset/foggy/foggy93.jpg
# /content/dataset/foggy/foggy266.jpg
# /content/dataset/foggy/foggy156.jpg
# /content/dataset/foggy/foggy269.jpg
# /content/dataset/foggy/foggy149.jpg
# /content/dataset/foggy/foggy180.jpg
# /content/dataset/foggy/foggy193.jpg
# /content/dataset/foggy/foggy152.jpg
# /content/dataset/foggy/foggy178.jpg
# /content/dataset/foggy/foggy230.jpg
# /content/dataset/foggy/foggy208.jpeg
# /content/dataset/foggy/foggy223.jpg
# /content/dataset/foggy/foggy299.jpg
# /content/dataset/foggy/foggy18.jpg
# /content/dataset/foggy/foggy245.jpg
# /content/dataset/foggy/foggy243.jpg
# /content/dataset/foggy/foggy252.jpg
# /content/dataset/foggy/foggy218.jpg
# /content/dataset/foggy/foggy46.jpg
# /content/dataset/foggy/foggy160.jpg
# /content/dataset/foggy/foggy172.jpg
# /content/dataset/foggy/foggy88.jpg
# /content/dataset/foggy/foggy51.jpg
# /content/dataset/foggy/foggy106.jpg
# /content/dataset/foggy/foggy5.jpg
# /content/dataset/foggy/foggy183.jpg
# /content/dataset/foggy/foggy272.jpg
# /content/dataset/foggy/foggy128.jpg
# /content/dataset/foggy/foggy232.jpg
# /content/dataset/foggy/foggy153.jpg
# /content/dataset/foggy/foggy185.jpg
# /content/dataset/foggy/foggy9.jpg
# /content/dataset/foggy/foggy122.jpg
# /content/dataset/foggy/foggy173.jpg
# /content/dataset/foggy/foggy297.jpg
# /content/dataset/foggy/foggy143.jpg
# /content/dataset/foggy/foggy179.jpg
# /content/dataset/foggy/foggy99.jpg
# /content/dataset/foggy/foggy21.jpg
# /content/dataset/foggy/foggy195.jpg
# /content/dataset/foggy/foggy255.jpg
# /content/dataset/foggy/foggy238.jpg
# /content/dataset/foggy/foggy234.jpg
# /content/dataset/foggy/foggy288.jpg
# /content/dataset/foggy/foggy92.jpg
# /content/dataset/foggy/foggy53.jpg
# /content/dataset/foggy/foggy294.jpg
# /content/dataset/foggy/foggy262.jpg
# /content/dataset/foggy/foggy134.png
# /content/dataset/foggy/foggy71.jpg
# /content/dataset/foggy/foggy82.jpg
# /content/dataset/foggy/foggy65.jpg
# /content/dataset/foggy/foggy120.jpg
# /content/dataset/foggy/foggy117.jpg
# /content/dataset/foggy/foggy64.jpg
# /content/dataset/foggy/foggy260.jpg
# /content/dataset/sunrise/sunrise178.jpg
# /content/dataset/sunrise/sunrise80.jpg
# /content/dataset/sunrise/sunrise336.jpg
# /content/dataset/sunrise/sunrise252.jpg
# /content/dataset/sunrise/sunrise223.jpg
# /content/dataset/sunrise/sunrise39.jpg
# /content/dataset/sunrise/sunrise110.jpg
# /content/dataset/sunrise/sunrise289.jpg
# /content/dataset/sunrise/sunrise259.jpg
# /content/dataset/sunrise/sunrise4.jpg
# /content/dataset/sunrise/sunrise67.jpg
# /content/dataset/sunrise/sunrise349.jpg
# /content/dataset/sunrise/sunrise246.jpg
# /content/dataset/sunrise/sunrise168.jpg
# /content/dataset/sunrise/sunrise165.jpg
# /content/dataset/sunrise/sunrise21.jpg
# /content/dataset/sunrise/sunrise82.jpg
# /content/dataset/sunrise/sunrise180.jpg
# /content/dataset/sunrise/sunrise233.jpg
# /content/dataset/sunrise/sunrise47.jpg
# /content/dataset/sunrise/sunrise33.jpg
# /content/dataset/sunrise/sunrise265.jpg
# /content/dataset/sunrise/sunrise8.jpg
# /content/dataset/sunrise/sunrise318.jpg
# /content/dataset/sunrise/sunrise237.jpg
# /content/dataset/sunrise/sunrise46.jpg
# /content/dataset/sunrise/sunrise240.jpg
# /content/dataset/sunrise/sunrise162.jpg
# /content/dataset/sunrise/sunrise212.jpg
# /content/dataset/sunrise/sunrise61.jpg
# /content/dataset/sunrise/sunrise313.jpg
# /content/dataset/sunrise/sunrise256.jpg
# /content/dataset/sunrise/sunrise55.jpg
# /content/dataset/sunrise/sunrise263.jpg
# /content/dataset/sunrise/sunrise150.jpg
# /content/dataset/sunrise/sunrise98.jpg
# /content/dataset/sunrise/sunrise283.jpg
# /content/dataset/sunrise/sunrise204.jpg
# /content/dataset/sunrise/sunrise86.jpg
# /content/dataset/sunrise/sunrise346.jpg
# /content/dataset/sunrise/sunrise172.jpg
# /content/dataset/sunrise/sunrise293.jpg
# /content/dataset/sunrise/sunrise257.jpg
# /content/dataset/sunrise/sunrise157.jpg
# /content/dataset/sunrise/sunrise338.jpg
# /content/dataset/sunrise/sunrise18.jpg
# /content/dataset/sunrise/sunrise93.jpg
# /content/dataset/sunrise/sunrise260.jpg
# /content/dataset/sunrise/sunrise290.jpg
# /content/dataset/sunrise/sunrise303.jpg
# /content/dataset/sunrise/sunrise262.jpg
# /content/dataset/sunrise/sunrise69.jpg
# /content/dataset/sunrise/sunrise345.jpg
# /content/dataset/sunrise/sunrise65.jpg
# /content/dataset/sunrise/sunrise5.jpg
# /content/dataset/sunrise/sunrise113.jpg
# /content/dataset/sunrise/sunrise267.jpg
# /content/dataset/sunrise/sunrise45.jpg
# /content/dataset/sunrise/sunrise187.jpg
# /content/dataset/sunrise/sunrise195.jpg
# /content/dataset/sunrise/sunrise1.jpg
# /content/dataset/sunrise/sunrise174.jpg
# /content/dataset/sunrise/sunrise181.jpg
# /content/dataset/sunrise/sunrise285.jpg
# /content/dataset/sunrise/sunrise308.jpg
# /content/dataset/sunrise/sunrise301.jpg
# /content/dataset/sunrise/sunrise295.jpg
# /content/dataset/sunrise/sunrise182.jpg
# /content/dataset/sunrise/sunrise185.jpg
# /content/dataset/sunrise/sunrise288.jpg
# /content/dataset/sunrise/sunrise194.jpg
# /content/dataset/sunrise/sunrise220.jpg
# /content/dataset/sunrise/sunrise143.jpg
# /content/dataset/sunrise/sunrise333.jpg
# /content/dataset/sunrise/sunrise112.jpg
# /content/dataset/sunrise/sunrise179.jpg
# /content/dataset/sunrise/sunrise121.jpg
# /content/dataset/sunrise/sunrise142.jpg
# /content/dataset/sunrise/sunrise78.jpg
# /content/dataset/sunrise/sunrise159.jpg
# /content/dataset/sunrise/sunrise10.jpg
# /content/dataset/sunrise/sunrise100.jpg
# /content/dataset/sunrise/sunrise87.jpg
# /content/dataset/sunrise/sunrise31.jpg
# /content/dataset/sunrise/sunrise184.jpg
# /content/dataset/sunrise/sunrise9.jpg
# /content/dataset/sunrise/sunrise90.jpg
# /content/dataset/sunrise/sunrise268.jpg
# /content/dataset/sunrise/sunrise163.jpg
# /content/dataset/sunrise/sunrise229.jpg
# /content/dataset/sunrise/sunrise213.jpg
# /content/dataset/sunrise/sunrise35.jpg
# /content/dataset/sunrise/sunrise277.jpg
# /content/dataset/sunrise/sunrise148.jpg
# /content/dataset/sunrise/sunrise214.jpg
# /content/dataset/sunrise/sunrise119.jpg
# /content/dataset/sunrise/sunrise226.jpg
# /content/dataset/sunrise/sunrise328.jpg
# /content/dataset/sunrise/sunrise115.jpg
# /content/dataset/sunrise/sunrise149.jpg
# /content/dataset/sunrise/sunrise279.jpg
# /content/dataset/sunrise/sunrise64.jpg
# /content/dataset/sunrise/sunrise307.jpg
# /content/dataset/sunrise/sunrise41.jpg
# /content/dataset/sunrise/sunrise43.jpg
# /content/dataset/sunrise/sunrise34.jpg
# /content/dataset/sunrise/sunrise26.jpg
# /content/dataset/sunrise/sunrise22.jpg
# /content/dataset/sunrise/sunrise350.jpg
# /content/dataset/sunrise/sunrise244.jpg
# /content/dataset/sunrise/sunrise106.jpg
# /content/dataset/sunrise/sunrise186.jpg
# /content/dataset/sunrise/sunrise89.jpeg
# /content/dataset/sunrise/sunrise29.jpg
# /content/dataset/sunrise/sunrise254.jpg
# /content/dataset/sunrise/sunrise287.jpg
# /content/dataset/sunrise/sunrise322.jpg
# /content/dataset/sunrise/sunrise215.jpg
# /content/dataset/sunrise/sunrise85.jpg
# /content/dataset/sunrise/sunrise183.jpg
# /content/dataset/sunrise/sunrise108.jpg
# /content/dataset/sunrise/sunrise312.jpg
# /content/dataset/sunrise/sunrise311.jpg
# /content/dataset/sunrise/sunrise145.jpg
# /content/dataset/sunrise/sunrise221.jpg
# /content/dataset/sunrise/sunrise228.jpg
# /content/dataset/sunrise/sunrise326.jpg
# /content/dataset/sunrise/sunrise211.jpg
# /content/dataset/sunrise/sunrise40.jpg
# /content/dataset/sunrise/sunrise92.jpg
# /content/dataset/sunrise/sunrise167.jpg
# /content/dataset/sunrise/sunrise339.jpg
# /content/dataset/sunrise/sunrise225.jpg
# /content/dataset/sunrise/sunrise17.jpg
# /content/dataset/sunrise/sunrise341.jpg
# /content/dataset/sunrise/sunrise164.jpg
# /content/dataset/sunrise/sunrise266.jpg
# /content/dataset/sunrise/sunrise135.jpg
# /content/dataset/sunrise/sunrise97.jpg
# /content/dataset/sunrise/sunrise138.jpg
# /content/dataset/sunrise/sunrise139.jpg
# /content/dataset/sunrise/sunrise42.jpg
# /content/dataset/sunrise/sunrise171.jpg
# /content/dataset/sunrise/sunrise11.jpg
# /content/dataset/sunrise/sunrise152.jpg
# /content/dataset/sunrise/sunrise255.jpg
# /content/dataset/sunrise/sunrise74.jpg
# /content/dataset/sunrise/sunrise54.jpg
# /content/dataset/sunrise/sunrise247.jpg
# /content/dataset/sunrise/sunrise278.jpg
# /content/dataset/sunrise/sunrise270.jpg
# /content/dataset/sunrise/sunrise88.jpg
# /content/dataset/sunrise/sunrise261.jpg
# /content/dataset/sunrise/sunrise114.jpg
# /content/dataset/sunrise/sunrise129.jpg
# /content/dataset/sunrise/sunrise127.jpg
# /content/dataset/sunrise/sunrise175.jpg
# /content/dataset/sunrise/sunrise320.jpg
# /content/dataset/sunrise/sunrise249.jpg
# /content/dataset/sunrise/sunrise62.jpg
# /content/dataset/sunrise/sunrise291.jpg
# /content/dataset/sunrise/sunrise201.jpg
# /content/dataset/sunrise/sunrise258.jpg
# /content/dataset/sunrise/sunrise3.jpg
# /content/dataset/sunrise/sunrise197.jpg
# /content/dataset/sunrise/sunrise188.jpg
# /content/dataset/sunrise/sunrise49.jpg
# /content/dataset/sunrise/sunrise155.jpg
# /content/dataset/sunrise/sunrise105.jpg
# /content/dataset/sunrise/sunrise72.jpg
# /content/dataset/sunrise/sunrise73.jpg
# /content/dataset/sunrise/sunrise281.jpg
# /content/dataset/sunrise/sunrise123.jpg
# /content/dataset/sunrise/sunrise124.jpg
# /content/dataset/sunrise/sunrise253.jpg
# /content/dataset/sunrise/sunrise302.jpg
# /content/dataset/sunrise/sunrise169.jpg
# /content/dataset/sunrise/sunrise199.jpg
# /content/dataset/sunrise/sunrise144.jpg
# /content/dataset/sunrise/sunrise156.jpg
# /content/dataset/sunrise/sunrise134.jpg
# /content/dataset/sunrise/sunrise286.jpg
# /content/dataset/sunrise/sunrise76.jpg
# /content/dataset/sunrise/sunrise77.jpg
# /content/dataset/sunrise/sunrise38.jpg
# /content/dataset/sunrise/sunrise126.jpg
# /content/dataset/sunrise/sunrise132.jpg
# /content/dataset/sunrise/sunrise15.jpg
# /content/dataset/sunrise/sunrise319.jpg
# /content/dataset/sunrise/sunrise117.jpg
# /content/dataset/sunrise/sunrise342.jpg
# /content/dataset/sunrise/sunrise284.jpg
# /content/dataset/sunrise/sunrise297.jpg
# /content/dataset/sunrise/sunrise130.jpg
# /content/dataset/sunrise/sunrise208.jpg
# /content/dataset/sunrise/sunrise48.jpg
# /content/dataset/sunrise/sunrise202.jpg
# /content/dataset/sunrise/sunrise348.jpg
# /content/dataset/sunrise/sunrise216.jpg
# /content/dataset/sunrise/sunrise209.jpg
# /content/dataset/sunrise/sunrise340.jpg
# /content/dataset/sunrise/sunrise314.jpg
# /content/dataset/sunrise/sunrise24.jpg
# /content/dataset/sunrise/sunrise248.jpg
# /content/dataset/sunrise/sunrise101.jpg
# /content/dataset/sunrise/sunrise206.jpg
# /content/dataset/sunrise/sunrise217.jpg
# /content/dataset/sunrise/sunrise230.jpg
# /content/dataset/sunrise/sunrise198.jpg
# /content/dataset/sunrise/sunrise219.jpg
# /content/dataset/sunrise/sunrise191.jpg
# /content/dataset/sunrise/sunrise304.jpg
# /content/dataset/sunrise/sunrise300.jpg
# /content/dataset/sunrise/sunrise190.jpg
# /content/dataset/sunrise/sunrise120.jpg
# /content/dataset/sunrise/sunrise6.jpg
# /content/dataset/sunrise/sunrise27.jpg
# /content/dataset/sunrise/sunrise137.jpg
# /content/dataset/sunrise/sunrise227.jpg
# /content/dataset/sunrise/sunrise16.jpg
# /content/dataset/sunrise/sunrise200.jpg
# /content/dataset/sunrise/sunrise94.jpg
# /content/dataset/sunrise/sunrise321.jpg
# /content/dataset/sunrise/sunrise337.jpg
# /content/dataset/sunrise/sunrise30.jpg
# /content/dataset/sunrise/sunrise275.jpg
# /content/dataset/sunrise/sunrise203.jpg
# /content/dataset/sunrise/sunrise334.jpg
# /content/dataset/sunrise/sunrise122.jpg
# /content/dataset/sunrise/sunrise218.jpg
# /content/dataset/sunrise/sunrise151.jpg
# /content/dataset/sunrise/sunrise51.jpg
# /content/dataset/sunrise/sunrise44.jpg
# /content/dataset/sunrise/sunrise242.jpg
# /content/dataset/sunrise/sunrise315.jpg
# /content/dataset/sunrise/sunrise160.jpg
# /content/dataset/sunrise/sunrise28.jpg
# /content/dataset/sunrise/sunrise96.jpg
# /content/dataset/sunrise/sunrise330.jpg
# /content/dataset/sunrise/sunrise173.jpg
# /content/dataset/sunrise/sunrise243.jpg
# /content/dataset/sunrise/sunrise50.jpg
# /content/dataset/sunrise/sunrise56.jpg
# /content/dataset/sunrise/sunrise99.jpg
# /content/dataset/sunrise/sunrise154.jpg
# /content/dataset/sunrise/sunrise324.jpg
# /content/dataset/sunrise/sunrise79.jpg
# /content/dataset/sunrise/sunrise128.jpg
# /content/dataset/sunrise/sunrise147.jpg
# /content/dataset/sunrise/sunrise296.jpg
# /content/dataset/sunrise/sunrise7.jpg
# /content/dataset/sunrise/sunrise136.jpg
# /content/dataset/sunrise/sunrise205.jpg
# /content/dataset/sunrise/sunrise316.jpg
# /content/dataset/sunrise/sunrise196.jpg
# /content/dataset/sunrise/sunrise158.jpg
# /content/dataset/sunrise/sunrise325.jpg
# /content/dataset/sunrise/sunrise294.jpg
# /content/dataset/sunrise/sunrise299.jpg
# /content/dataset/sunrise/sunrise102.jpg
# /content/dataset/sunrise/sunrise306.jpg
# /content/dataset/sunrise/sunrise309.jpg
# /content/dataset/sunrise/sunrise177.jpg
# /content/dataset/sunrise/sunrise63.jpg
# /content/dataset/sunrise/sunrise236.jpg
# /content/dataset/sunrise/sunrise84.jpg
# /content/dataset/sunrise/sunrise193.jpg
# /content/dataset/sunrise/sunrise70.jpg
# /content/dataset/sunrise/sunrise14.jpg
# /content/dataset/sunrise/sunrise166.jpg
# /content/dataset/sunrise/sunrise71.jpg
# /content/dataset/sunrise/sunrise37.jpg
# /content/dataset/sunrise/sunrise222.jpg
# /content/dataset/sunrise/sunrise20.jpg
# /content/dataset/sunrise/sunrise210.jpg
# /content/dataset/sunrise/sunrise57.jpg
# /content/dataset/sunrise/sunrise327.jpg
# /content/dataset/sunrise/sunrise282.jpg
# /content/dataset/sunrise/sunrise192.jpg
# /content/dataset/sunrise/sunrise329.jpg
# /content/dataset/sunrise/sunrise335.jpg
# /content/dataset/sunrise/sunrise75.jpg
# /content/dataset/sunrise/sunrise12.jpg
# /content/dataset/sunrise/sunrise269.jpg
# /content/dataset/sunrise/sunrise239.jpg
# /content/dataset/sunrise/sunrise280.jpg
# /content/dataset/sunrise/sunrise111.jpg
# /content/dataset/sunrise/sunrise189.jpg
# /content/dataset/sunrise/sunrise207.jpg
# /content/dataset/sunrise/sunrise276.jpg
# /content/dataset/sunrise/sunrise235.jpg
# /content/dataset/sunrise/sunrise83.jpg
# /content/dataset/sunrise/sunrise109.jpg
# /content/dataset/sunrise/sunrise95.jpg
# /content/dataset/sunrise/sunrise133.jpg
# /content/dataset/sunrise/sunrise251.jpg
# /content/dataset/sunrise/sunrise118.jpg
# /content/dataset/sunrise/sunrise131.jpg
# /content/dataset/sunrise/sunrise59.jpg
# /content/dataset/sunrise/sunrise104.jpg
# /content/dataset/sunrise/sunrise161.jpg
# /content/dataset/sunrise/sunrise52.jpg
# /content/dataset/sunrise/sunrise231.jpg
# /content/dataset/sunrise/sunrise250.jpg
# /content/dataset/sunrise/sunrise53.jpg
# /content/dataset/sunrise/sunrise25.jpg
# /content/dataset/sunrise/sunrise273.jpg
# /content/dataset/sunrise/sunrise58.jpg
# /content/dataset/sunrise/sunrise317.jpg
# /content/dataset/sunrise/sunrise91.jpg
# /content/dataset/sunrise/sunrise36.jpg
# /content/dataset/sunrise/sunrise331.jpg
# /content/dataset/sunrise/sunrise344.jpg
# /content/dataset/sunrise/sunrise2.jpg
# /content/dataset/sunrise/sunrise232.jpg
# /content/dataset/sunrise/sunrise238.jpg
# /content/dataset/sunrise/sunrise343.jpg
# /content/dataset/sunrise/sunrise274.jpg
# /content/dataset/sunrise/sunrise271.jpg
# /content/dataset/sunrise/sunrise23.jpg
# /content/dataset/sunrise/sunrise241.jpg
# /content/dataset/sunrise/sunrise170.jpg
# /content/dataset/sunrise/sunrise332.jpg
# /content/dataset/sunrise/sunrise116.jpg
# /content/dataset/sunrise/sunrise347.jpg
# /content/dataset/sunrise/sunrise153.jpg
# /content/dataset/sunrise/sunrise264.jpg
# /content/dataset/sunrise/sunrise245.jpg
# /content/dataset/sunrise/sunrise107.jpg
# /content/dataset/sunrise/sunrise310.jpg
# /content/dataset/sunrise/sunrise19.jpg
# /content/dataset/sunrise/sunrise103.jpg
# /content/dataset/sunrise/sunrise68.jpg
# /content/dataset/sunrise/sunrise272.jpg
# /content/dataset/sunrise/sunrise60.jpg
# /content/dataset/sunrise/sunrise13.jpg
# /content/dataset/sunrise/sunrise323.jpg
# /content/dataset/sunrise/sunrise32.jpg
# /content/dataset/sunrise/sunrise81.jpg
# /content/dataset/sunrise/sunrise140.jpg
# /content/dataset/sunrise/sunrise141.jpg
# /content/dataset/sunrise/sunrise224.jpg
# /content/dataset/sunrise/sunrise305.jpg
# /content/dataset/sunrise/sunrise146.jpg
# /content/dataset/sunrise/sunrise292.jpg
# /content/dataset/sunrise/sunrise66.jpg
# /content/dataset/sunrise/sunrise125.jpg
# /content/dataset/sunrise/sunrise176.jpg
# /content/dataset/sunrise/sunrise298.jpg
# /content/dataset/sunrise/sunrise234.jpg
# /content/dataset/alien_test/foggy_2.jpg
# /content/dataset/alien_test/foggy_4.jpg
# /content/dataset/alien_test/foggy_3.jpg
# /content/dataset/alien_test/foggy_6.jpg
# /content/dataset/alien_test/Cloud_2.jpg
# /content/dataset/alien_test/rain_5.jpg
# /content/dataset/alien_test/rain_3.jpg
# /content/dataset/alien_test/sunrise_5.jpg
# /content/dataset/alien_test/shine_3.jpg
# /content/dataset/alien_test/sunrise_7.jpg
# /content/dataset/alien_test/Cloud_1.png
# /content/dataset/alien_test/rain_2.png
# /content/dataset/alien_test/rain_6.jpg
# /content/dataset/alien_test/foggy_10.jpg
# /content/dataset/alien_test/Cloud_4.jpg
# /content/dataset/alien_test/sunrise_1.jpg
# /content/dataset/alien_test/sunrise_4.jpg
# /content/dataset/alien_test/foggy_8.jpg
# /content/dataset/alien_test/Cloud_3.jpeg
# /content/dataset/alien_test/shine_2.jpg
# /content/dataset/alien_test/sunrise_3.jpg
# /content/dataset/alien_test/sunrise_2.jpg
# /content/dataset/alien_test/foggy_1.jpg
# /content/dataset/alien_test/foggy_7.jpg
# /content/dataset/alien_test/foggy_5.jpg
# /content/dataset/alien_test/sunrise_6.jpg
# /content/dataset/alien_test/foggy_9.jpg
# /content/dataset/alien_test/rain_1.jpg
# /content/dataset/alien_test/rain_4.jpg
# /content/dataset/alien_test/shine_1.jpg
# /content/dataset/cloudy/cloudy37.jpg
# /content/dataset/cloudy/cloudy251.jpg
# /content/dataset/cloudy/cloudy130.jpg
# /content/dataset/cloudy/cloudy299.jpg
# /content/dataset/cloudy/cloudy22.jpg
# /content/dataset/cloudy/cloudy14.jpg
# /content/dataset/cloudy/cloudy33.jpg
# /content/dataset/cloudy/cloudy87.jpg
# /content/dataset/cloudy/cloudy29.jpg
# /content/dataset/cloudy/cloudy286.jpg
# /content/dataset/cloudy/cloudy67.jpg
# /content/dataset/cloudy/cloudy91.jpg
# /content/dataset/cloudy/cloudy178.jpg
# /content/dataset/cloudy/cloudy90.jpg
# /content/dataset/cloudy/cloudy120.jpg
# /content/dataset/cloudy/cloudy89.jpg
# /content/dataset/cloudy/cloudy112.jpg
# /content/dataset/cloudy/cloudy54.jpg
# /content/dataset/cloudy/cloudy8.jpg
# /content/dataset/cloudy/cloudy243.jpg
# /content/dataset/cloudy/cloudy15.jpg
# /content/dataset/cloudy/cloudy218.jpg
# /content/dataset/cloudy/cloudy292.jpg
# /content/dataset/cloudy/cloudy254.jpg
# /content/dataset/cloudy/cloudy180.jpg
# /content/dataset/cloudy/cloudy135.jpg
# /content/dataset/cloudy/cloudy300.jpg
# /content/dataset/cloudy/cloudy245.jpg
# /content/dataset/cloudy/cloudy231.jpg
# /content/dataset/cloudy/cloudy284.jpg
# /content/dataset/cloudy/cloudy109.jpg
# /content/dataset/cloudy/cloudy39.jpg
# /content/dataset/cloudy/cloudy30.jpg
# /content/dataset/cloudy/cloudy258.jpg
# /content/dataset/cloudy/cloudy187.jpg
# /content/dataset/cloudy/cloudy12.jpg
# /content/dataset/cloudy/cloudy23.jpg
# /content/dataset/cloudy/cloudy99.jpg
# /content/dataset/cloudy/cloudy247.jpg
# /content/dataset/cloudy/cloudy96.jpg
# /content/dataset/cloudy/cloudy66.jpg
# /content/dataset/cloudy/cloudy25.jpg
# /content/dataset/cloudy/cloudy204.jpg
# /content/dataset/cloudy/cloudy132.jpg
# /content/dataset/cloudy/cloudy137.jpg
# /content/dataset/cloudy/cloudy58.jpg
# /content/dataset/cloudy/cloudy105.jpg
# /content/dataset/cloudy/cloudy62.jpg
# /content/dataset/cloudy/cloudy250.jpg
# /content/dataset/cloudy/cloudy32.jpg
# /content/dataset/cloudy/cloudy10.jpg
# /content/dataset/cloudy/cloudy183.jpg
# /content/dataset/cloudy/cloudy237.jpg
# /content/dataset/cloudy/cloudy34.jpg
# /content/dataset/cloudy/cloudy212.jpg
# /content/dataset/cloudy/cloudy207.jpg
# /content/dataset/cloudy/cloudy134.jpg
# /content/dataset/cloudy/cloudy147.jpg
# /content/dataset/cloudy/cloudy3.jpg
# /content/dataset/cloudy/cloudy267.jpg
# /content/dataset/cloudy/cloudy171.jpg
# /content/dataset/cloudy/cloudy161.jpg
# /content/dataset/cloudy/cloudy211.jpg
# /content/dataset/cloudy/cloudy28.jpg
# /content/dataset/cloudy/cloudy153.jpg
# /content/dataset/cloudy/cloudy97.jpg
# /content/dataset/cloudy/cloudy241.jpg
# /content/dataset/cloudy/cloudy2.jpg
# /content/dataset/cloudy/cloudy121.jpg
# /content/dataset/cloudy/cloudy9.jpg
# /content/dataset/cloudy/cloudy285.jpg
# /content/dataset/cloudy/cloudy114.jpg
# /content/dataset/cloudy/cloudy215.jpg
# /content/dataset/cloudy/cloudy253.jpg
# /content/dataset/cloudy/cloudy244.jpg
# /content/dataset/cloudy/cloudy198.jpg
# /content/dataset/cloudy/cloudy266.jpg
# /content/dataset/cloudy/cloudy158.jpg
# /content/dataset/cloudy/cloudy71.jpg
# /content/dataset/cloudy/cloudy68.jpg
# /content/dataset/cloudy/cloudy49.jpg
# /content/dataset/cloudy/cloudy19.jpg
# /content/dataset/cloudy/cloudy61.jpg
# /content/dataset/cloudy/cloudy85.jpg
# /content/dataset/cloudy/cloudy275.jpg
# /content/dataset/cloudy/cloudy126.jpg
# /content/dataset/cloudy/cloudy263.jpg
# /content/dataset/cloudy/cloudy255.jpg
# /content/dataset/cloudy/cloudy76.jpg
# /content/dataset/cloudy/cloudy278.jpg
# /content/dataset/cloudy/cloudy78.jpg
# /content/dataset/cloudy/cloudy196.jpg
# /content/dataset/cloudy/cloudy164.jpg
# /content/dataset/cloudy/cloudy140.jpg
# /content/dataset/cloudy/cloudy246.jpg
# /content/dataset/cloudy/cloudy268.jpg
# /content/dataset/cloudy/cloudy156.jpg
# /content/dataset/cloudy/cloudy122.jpg
# /content/dataset/cloudy/cloudy50.jpg
# /content/dataset/cloudy/cloudy154.jpg
# /content/dataset/cloudy/cloudy11.jpg
# /content/dataset/cloudy/cloudy117.jpg
# /content/dataset/cloudy/cloudy56.jpg
# /content/dataset/cloudy/cloudy188.jpg
# /content/dataset/cloudy/cloudy35.jpg
# /content/dataset/cloudy/cloudy69.jpg
# /content/dataset/cloudy/cloudy21.jpg
# /content/dataset/cloudy/cloudy271.jpg
# /content/dataset/cloudy/cloudy290.jpg
# /content/dataset/cloudy/cloudy179.jpg
# /content/dataset/cloudy/cloudy65.jpg
# /content/dataset/cloudy/cloudy208.jpg
# /content/dataset/cloudy/cloudy287.jpg
# /content/dataset/cloudy/cloudy234.jpg
# /content/dataset/cloudy/cloudy53.jpg
# /content/dataset/cloudy/cloudy86.jpg
# /content/dataset/cloudy/cloudy42.jpg
# /content/dataset/cloudy/cloudy111.jpg
# /content/dataset/cloudy/cloudy185.jpg
# /content/dataset/cloudy/cloudy55.jpg
# /content/dataset/cloudy/cloudy64.jpg
# /content/dataset/cloudy/cloudy293.jpg
# /content/dataset/cloudy/cloudy291.jpg
# /content/dataset/cloudy/cloudy210.jpg
# /content/dataset/cloudy/cloudy297.jpg
# /content/dataset/cloudy/cloudy222.jpg
# /content/dataset/cloudy/cloudy206.jpg
# /content/dataset/cloudy/cloudy83.jpg
# /content/dataset/cloudy/cloudy280.jpg
# /content/dataset/cloudy/cloudy159.jpg
# /content/dataset/cloudy/cloudy272.jpg
# /content/dataset/cloudy/cloudy113.jpg
# /content/dataset/cloudy/cloudy201.jpg
# /content/dataset/cloudy/cloudy281.jpg
# /content/dataset/cloudy/cloudy128.jpg
# /content/dataset/cloudy/cloudy63.jpg
# /content/dataset/cloudy/cloudy176.jpg
# /content/dataset/cloudy/cloudy20.jpg
# /content/dataset/cloudy/cloudy248.jpg
# /content/dataset/cloudy/cloudy73.jpg
# /content/dataset/cloudy/cloudy283.jpg
# /content/dataset/cloudy/cloudy16.jpg
# /content/dataset/cloudy/cloudy143.jpg
# /content/dataset/cloudy/cloudy136.jpg
# /content/dataset/cloudy/cloudy124.jpg
# /content/dataset/cloudy/cloudy138.jpg
# /content/dataset/cloudy/cloudy149.jpg
# /content/dataset/cloudy/cloudy168.jpg
# /content/dataset/cloudy/cloudy279.jpg
# /content/dataset/cloudy/cloudy235.jpg
# /content/dataset/cloudy/cloudy282.jpg
# /content/dataset/cloudy/cloudy274.jpg
# /content/dataset/cloudy/cloudy47.jpg
# /content/dataset/cloudy/cloudy38.jpg
# /content/dataset/cloudy/cloudy260.jpg
# /content/dataset/cloudy/cloudy217.jpg
# /content/dataset/cloudy/cloudy45.jpg
# /content/dataset/cloudy/cloudy27.jpg
# /content/dataset/cloudy/cloudy24.jpg
# /content/dataset/cloudy/cloudy261.jpg
# /content/dataset/cloudy/cloudy226.jpg
# /content/dataset/cloudy/cloudy163.jpg
# /content/dataset/cloudy/cloudy265.jpg
# /content/dataset/cloudy/cloudy60.jpg
# /content/dataset/cloudy/cloudy145.jpg
# /content/dataset/cloudy/cloudy72.jpg
# /content/dataset/cloudy/cloudy270.jpg
# /content/dataset/cloudy/cloudy150.jpg
# /content/dataset/cloudy/cloudy175.jpg
# /content/dataset/cloudy/cloudy131.jpg
# /content/dataset/cloudy/cloudy41.jpg
# /content/dataset/cloudy/cloudy5.jpg
# /content/dataset/cloudy/cloudy127.jpg
# /content/dataset/cloudy/cloudy141.jpg
# /content/dataset/cloudy/cloudy298.jpg
# /content/dataset/cloudy/cloudy52.jpg
# /content/dataset/cloudy/cloudy13.jpg
# /content/dataset/cloudy/cloudy213.jpg
# /content/dataset/cloudy/cloudy146.jpg
# /content/dataset/cloudy/cloudy103.jpg
# /content/dataset/cloudy/cloudy110.jpg
# /content/dataset/cloudy/cloudy191.jpg
# /content/dataset/cloudy/cloudy228.jpg
# /content/dataset/cloudy/cloudy276.jpg
# /content/dataset/cloudy/cloudy197.jpg
# /content/dataset/cloudy/cloudy123.jpg
# /content/dataset/cloudy/cloudy184.jpg
# /content/dataset/cloudy/cloudy192.jpg
# /content/dataset/cloudy/cloudy129.jpg
# /content/dataset/cloudy/cloudy57.jpg
# /content/dataset/cloudy/cloudy108.jpg
# /content/dataset/cloudy/cloudy95.jpg
# /content/dataset/cloudy/cloudy181.jpg
# /content/dataset/cloudy/cloudy252.jpg
# /content/dataset/cloudy/cloudy224.jpg
# /content/dataset/cloudy/cloudy295.jpg
# /content/dataset/cloudy/cloudy98.jpg
# /content/dataset/cloudy/cloudy151.jpg
# /content/dataset/cloudy/cloudy189.jpg
# /content/dataset/cloudy/cloudy174.jpg
# /content/dataset/cloudy/cloudy74.jpg
# /content/dataset/cloudy/cloudy219.jpg
# /content/dataset/cloudy/cloudy220.jpg
# /content/dataset/cloudy/cloudy160.jpg
# /content/dataset/cloudy/cloudy36.jpg
# /content/dataset/cloudy/cloudy1.jpg
# /content/dataset/cloudy/cloudy229.jpg
# /content/dataset/cloudy/cloudy205.jpg
# /content/dataset/cloudy/cloudy233.jpg
# /content/dataset/cloudy/cloudy227.jpg
# /content/dataset/cloudy/cloudy209.jpg
# /content/dataset/cloudy/cloudy242.jpg
# /content/dataset/cloudy/cloudy190.jpg
# /content/dataset/cloudy/cloudy165.jpg
# /content/dataset/cloudy/cloudy75.jpg
# /content/dataset/cloudy/cloudy223.jpg
# /content/dataset/cloudy/cloudy221.jpg
# /content/dataset/cloudy/cloudy101.jpg
# /content/dataset/cloudy/cloudy177.jpg
# /content/dataset/cloudy/cloudy17.jpg
# /content/dataset/cloudy/cloudy88.jpg
# /content/dataset/cloudy/cloudy6.jpg
# /content/dataset/cloudy/cloudy82.jpg
# /content/dataset/cloudy/cloudy172.jpg
# /content/dataset/cloudy/cloudy269.jpg
# /content/dataset/cloudy/cloudy216.jpg
# /content/dataset/cloudy/cloudy116.jpg
# /content/dataset/cloudy/cloudy262.jpg
# /content/dataset/cloudy/cloudy94.jpg
# /content/dataset/cloudy/cloudy133.jpg
# /content/dataset/cloudy/cloudy51.jpg
# /content/dataset/cloudy/cloudy194.jpg
# /content/dataset/cloudy/cloudy236.jpg
# /content/dataset/cloudy/cloudy152.jpg
# /content/dataset/cloudy/cloudy139.jpg
# /content/dataset/cloudy/cloudy44.jpg
# /content/dataset/cloudy/cloudy46.jpg
# /content/dataset/cloudy/cloudy40.jpg
# /content/dataset/cloudy/cloudy289.jpg
# /content/dataset/cloudy/cloudy296.jpg
# /content/dataset/cloudy/cloudy214.jpg
# /content/dataset/cloudy/cloudy119.jpg
# /content/dataset/cloudy/cloudy225.jpg
# /content/dataset/cloudy/cloudy92.jpg
# /content/dataset/cloudy/cloudy256.jpg
# /content/dataset/cloudy/cloudy115.jpg
# /content/dataset/cloudy/cloudy107.jpg
# /content/dataset/cloudy/cloudy142.jpg
# /content/dataset/cloudy/cloudy273.jpg
# /content/dataset/cloudy/cloudy102.jpg
# /content/dataset/cloudy/cloudy167.jpg
# /content/dataset/cloudy/cloudy77.jpg
# /content/dataset/cloudy/cloudy264.jpg
# /content/dataset/cloudy/cloudy202.jpg
# /content/dataset/cloudy/cloudy70.jpg
# /content/dataset/cloudy/cloudy186.jpg
# /content/dataset/cloudy/cloudy118.jpg
# /content/dataset/cloudy/cloudy182.jpg
# /content/dataset/cloudy/cloudy232.jpg
# /content/dataset/cloudy/cloudy257.jpg
# /content/dataset/cloudy/cloudy238.jpg
# /content/dataset/cloudy/cloudy93.jpg
# /content/dataset/cloudy/cloudy239.jpg
# /content/dataset/cloudy/cloudy157.jpg
# /content/dataset/cloudy/cloudy26.jpg
# /content/dataset/cloudy/cloudy4.jpg
# /content/dataset/cloudy/cloudy59.jpg
# /content/dataset/cloudy/cloudy249.jpg
# /content/dataset/cloudy/cloudy144.jpg
# /content/dataset/cloudy/cloudy294.jpg
# /content/dataset/cloudy/cloudy7.jpg
# /content/dataset/cloudy/cloudy240.jpg
# /content/dataset/cloudy/cloudy48.jpg
# /content/dataset/cloudy/cloudy173.jpg
# /content/dataset/cloudy/cloudy18.jpg
# /content/dataset/cloudy/cloudy288.jpg
# /content/dataset/cloudy/cloudy195.jpg
# /content/dataset/cloudy/cloudy193.jpg
# /content/dataset/cloudy/cloudy43.jpg
# /content/dataset/cloudy/cloudy203.jpg
# /content/dataset/cloudy/cloudy106.jpg
# /content/dataset/cloudy/cloudy104.jpg
# /content/dataset/cloudy/cloudy31.jpg
# /content/dataset/cloudy/cloudy81.jpg
# /content/dataset/cloudy/cloudy148.jpg
# /content/dataset/cloudy/cloudy199.jpg
# /content/dataset/cloudy/cloudy169.jpg
# /content/dataset/cloudy/cloudy162.jpg
# /content/dataset/cloudy/cloudy200.jpg
# /content/dataset/cloudy/cloudy84.jpg
# /content/dataset/cloudy/cloudy277.jpg
# /content/dataset/cloudy/cloudy259.jpg
# /content/dataset/cloudy/cloudy230.jpg
# /content/dataset/cloudy/cloudy100.jpg
# /content/dataset/cloudy/cloudy155.jpg
# /content/dataset/cloudy/cloudy170.jpg
# /content/dataset/cloudy/cloudy80.jpg
# /content/dataset/cloudy/cloudy166.jpg
# /content/dataset/cloudy/cloudy79.jpg
# /content/dataset/cloudy/cloudy125.jpg
# /content/sample_data/anscombe.json
# /content/sample_data/README.md
# /content/sample_data/california_housing_train.csv
# /content/sample_data/mnist_test.csv
# /content/sample_data/california_housing_test.csv
# /content/sample_data/mnist_train_small.csv

# %%
pip install numpy scikit-learn opencv-python matplotlib
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.8.0.76)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# The necessary libaries
import os
import numpy as np
import cv2
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score
import matplotlib.pyplot as plt
import joblib
import pandas as pd
from sklearn.decomposition import PCA

# %%
# Set dataset path
dataset_path = '/content/dataset'
# Image parameters
img_width, img_height = 150, 150

# %%
# Here we are  loading the  dataset
def import_dataset(dataset_path):
    pics = []
    tags = []
    for tag in os.listdir(dataset_path):
        tag_path = os.path.join(dataset_path, tag)
        if os.path.isdir(tag_path):
            for pic_file in os.listdir(tag_path):
                pic_path = os.path.join(tag_path, pic_file)
                pic = cv2.imread(pic_path)
                if pic is None:
                    continue  # Skip the pic if it cannot be loaded
                pic = cv2.resize(pic, (img_width, img_height))
                pics.append(pic)
                tags.append(tag)

    print(" The all of the  pics have been uploaded successfully.")
    return np.array(pics), np.array(tags)

pics, tags = import_dataset(dataset_path)

# Check if dataset is loaded correctly
if len(pics) == 0:
    raise ValueError("No pics loaded. Please check the dataset path and ensure it contains pics.")
# Out:
#  The all of the  pics have been uploaded successfully.

# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# Preparing the data

pics = pics.astype('float32') / 255.0  # Normalize pixel values
pics_flat = pics.reshape(len(pics), -1)  # Flatten images

# Encode labels
label_encoder = LabelEncoder()
tags_encoded = label_encoder.fit_transform(tags)

# Visualize label distribution
plt.figure(figsize=(10, 6))
plt.hist(tags_encoded, bins=len(set(tags_encoded)), edgecolor='black', color='lightcoral')
plt.title(' The Label Distribution', fontsize=16, fontweight='bold')
plt.xlabel('Encoded Labels', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(range(len(set(tags_encoded))), fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Here we are spliting the datas into two parts training and test sets

X_train, X_test, y_train, y_test = train_test_split(pics_flat, tags_encoded, test_size=0.2, random_state=42)

# %%
from sklearn.decomposition import PCA
import joblib
import matplotlib.pyplot as plt
import numpy as np

# Here we are using PCA to reduce data dimensions

n_components = 20  # desired number of principal components

pca = PCA(n_components=n_components)
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)
joblib.dump(pca, 'pca_model.pkl')

# Visualize explained variance ratio
plt.figure(figsize=(10, 6))
cumulative_variance = np.cumsum(pca.explained_variance_ratio_)
plt.plot(cumulative_variance, marker='o', linestyle='-', color='#1f77b4', linewidth=2, markersize=8, label='Cumulative Variance')
plt.fill_between(range(len(cumulative_variance)), cumulative_variance, color='#aec7e8', alpha=0.3)
plt.xlabel('Number of Components', fontsize=14)
plt.ylabel('Cumulative Explained Variance', fontsize=14)
plt.title('Cumulative Explained Variance Ratio by Number of Components', fontsize=16, fontweight='bold')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.axhline(y=0.95, color='green', linestyle='--', linewidth=1.5, label='95% Variance')
plt.axvline(x=np.argmax(cumulative_variance >= 0.95), color='green', linestyle='--', linewidth=1.5)
plt.legend(loc='best', fontsize=12)
plt.show()

# %%
# Training an SVM model with dimensionally reduced data

svm_model_pca = SVC(kernel='linear', probability=True)
svm_model_pca.fit(X_train_pca, y_train)

# Save the trained model and tag encoder

joblib.dump(svm_model_pca, 'weather_forecastion_svm_model_with_pca.pkl')
joblib.dump(label_encoder, 'tag_encoder.pkl')

print("Model training completed with PrincipalComponentAnalysis and saved as 'weather_forecastion_svm_model_with_pca.pkl'")
# Out:
# Model training completed with PrincipalComponentAnalysis and saved as 'weather_forecastion_svm_model_with_pca.pkl'

# %%
y_test_pred = svm_model_pca.predict(X_test_pca)

# %%
# Here we are Plotting the  test images with predictions
plt.figure(figsize=(12, 12))

for i in range(9):
    plt.subplot(3, 3, i + 1)
   # If X_test data is normalized, set it back to 0-255
    img = (X_test[i].reshape(img_width, img_height, 3) * 255).astype(np.uint8)
    plt.imshow(img)
    predicted_label = label_encoder.inverse_transform([y_test_pred[i]])[0]
    actual_label = label_encoder.inverse_transform([y_test[i]])[0]
    predicted_probability = svm_model_pca.predict_proba(X_test_pca)[i].max()

    plt.title(
        f"Actual: {actual_label}\nPredicted: {predicted_label}\nProbability: {predicted_probability:.2f}",
        fontsize=10,
        pad=10 # Add spaces for the title for better readability
    )
    plt.axis('off')

# Adjust editing to add space between images
plt.tight_layout(pad=3.0)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create DataFrame for predicted labels
df_pred = pd.DataFrame({'class_name': label_encoder.inverse_transform(y_test_pred)})

# Create a pie chart of class frequencies for predicted labels
plt.figure(figsize=(6, 6))
colors = plt.get_cmap('tab20c').colors  # Use a colormap for more vibrant colors
df_pred['class_name'].value_counts().plot(kind='pie', autopct='%1.1f%%',
                                          colors=colors, startangle=140,
                                          wedgeprops={'edgecolor': 'black'},
                                          textprops={'fontsize': 10, 'color': 'darkblue'})
plt.title('Class Frequencies (Predicted)', fontsize=14, fontweight='bold', color='darkblue')
plt.ylabel('')
plt.show()

# %%
# Create a bar chart of class frequencies for predicted labels
plt.figure(figsize=(10, 6))
colors = plt.cm.viridis(np.linspace(0, 1, len(df_pred['class_name'].unique())))
df_pred['class_name'].value_counts().plot(
    kind='bar',
    color=colors,
    edgecolor='black'
)
plt.title('Class Frequencies (Predicted)', fontsize=14, fontweight='bold')
plt.xlabel('Class Name', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
from IPython.display import HTML, display, clear_output
import ipywidgets as widgets
import random
import os
import cv2
import matplotlib.pyplot as plt
import joblib

# Define the path to the dataset
test_dir = '/content/dataset/alien_test/'

# Load the model, label encoder, and PCA model
model = joblib.load('weather_forecastion_svm_model_with_pca.pkl')
label_encoder = joblib.load('tag_encoder.pkl')
pca = joblib.load('pca_model.pkl')

# Define the image display function
def display_predicted_image(image, predicted_class):
    clear_output(wait=True)
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(f'Predicted: {predicted_class}')
    plt.axis('off')
    plt.show()

# Define the prediction function
def predict_weather(image_path):
    image = cv2.imread(image_path)
    if image is None:
        raise ValueError(f"Error loading image: {image_path}")
    resized_image = cv2.resize(image, (img_width, img_height))
    image_array = resized_image.astype('float32') / 255.0

    image_flat = image_array.reshape(1, -1)
    image_pca = pca.transform(image_flat)

    prediction = model.predict(image_pca)
    predicted_class = label_encoder.inverse_transform(prediction)[0]
    return predicted_class, image

# Create a button widget
button = widgets.Button(description="Show Random Image", style={'button_color': 'forestgreen', 'font_weight': 'bold', 'font-size': '20px', 'width': '400px', 'height': '70px'})
output = widgets.Output()

# Set background image
background_image_style = """
    <style>
        body {
            background-image: url("https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTBg3dONzLEZuWLSyBCiccqEeeQXqkyfVAV6A&s");
            background-size: cover;
        }
    </style>
"""
display(HTML(background_image_style))

display(button, output)

# Define the button click event
def on_button_clicked(b):
    random_image = random.choice(os.listdir(test_dir))
    image_path = os.path.join(test_dir, random_image)
    try:
        prediction, image = predict_weather(image_path)
        with output:
            print(f'The predicted weather condition is: {prediction}')
            print(f'Selected image: {random_image}')
            display_predicted_image(image, prediction)
    except ValueError as e:
        print(e)

# Attach the button click event to the button
button.on_click(on_button_clicked)
# Out:
#     <style>
#         body {
#             background-image: url("https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTBg3dONzLEZuWLSyBCiccqEeeQXqkyfVAV6A&s");
#             background-size: cover;
#         }
#     </style>
# Button(description='Show Random Image', style=ButtonStyle(button_color='forestgreen', font_weight='bold'))
# Output()

# %%
# Predictions on training data
train_predictions = svm_model_pca.predict(X_train_pca)
train_accuracy = accuracy_score(y_train, train_predictions)

# Predictions on test data
test_predictions = svm_model_pca.predict(X_test_pca)
test_accuracy = accuracy_score(y_test, test_predictions)

print(f"The Train Accuracy is: {train_accuracy * 100:.2f}%")
print(f"The Test Accuracy is: {test_accuracy * 100:.2f}%")
# Out:
# The Train Accuracy is: 73.57%
# The Test Accuracy is: 69.93%

# %%
# Load trained model and label encoder
svm_model_pca = joblib.load('weather_forecastion_svm_model_with_pca.pkl')
label_encoder = joblib.load('tag_encoder.pkl')
# Predictions using SVM model with PCA
svm_predictions_pca = svm_model_pca.predict(X_test_pca)
# Generate classification report
report = classification_report(y_test, svm_predictions_pca)
# Print classification report
print("Report of the Classification:")
print(report)
# Out:
# Report of the Classification:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         5
#            1       0.51      0.48      0.50        56
#            2       0.58      0.66      0.62        56
#            3       0.65      0.68      0.66        62
#            4       0.82      0.84      0.83        44
#            5       0.91      0.86      0.88        83
#
#     accuracy                           0.70       306
#    macro avg       0.58      0.59      0.58       306
# weighted avg       0.70      0.70      0.70       306
